#    ------------------------------------- -- 25.4/27.4 MB 203.4 kB/s eta 0:00:10
#    ------------------------------------- -- 25.4/27.4 MB 203.4 kB/s eta 0:00:10
#    ------------------------------------- -- 25.4/27.4 MB 203.4 kB/s eta 0:00:10
#    ------------------------------------- -- 25.4/27.4 MB 203.4 kB/s eta 0:00:10
#    ------------------------------------- -- 25.4/27.4 MB 203.4 kB/s eta 0:00:10
#    ------------------------------------- -- 25.4/27.4 MB 203.4 kB/s eta 0:00:10
#    ------------------------------------- -- 25.7/27.4 MB 198.4 kB/s eta 0:00:09
#    ------------------------------------- -- 25.7/27.4 MB 198.4 kB/s eta 0:00:09
#    ------------------------------------- -- 25.7/27.4 MB 198.4 kB/s eta 0:00:09
#    ------------------------------------- -- 25.7/27.4 MB 198.4 kB/s eta 0:00:09
#    ------------------------------------- -- 25.7/27.4 MB 198.4 kB/s eta 0:00:09
#    ------------------------------------- -- 26.0/27.4 MB 201.0 kB/s eta 0:00:07
#    ------------------------------------- -- 26.0/27.4 MB 201.0 kB/s eta 0:00:07
#    ------------------------------------- -- 26.0/27.4 MB 201.0 kB/s eta 0:00:07
#    ------------------------------------- -- 26.0/27.4 MB 201.0 kB/s eta 0:00:07
#    ------------------------------------- -- 26.0/27.4 MB 201.0 kB/s eta 0:00:07
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.2/27.4 MB 202.2 kB/s eta 0:00:06
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    -------------------------------------- - 26.5/27.4 MB 199.2 kB/s eta 0:00:05
#    ---------------------------------------  26.7/27.4 MB 199.8 kB/s eta 0:00:04
#    ---------------------------------------  26.7/27.4 MB 199.8 kB/s eta 0:00:04
#    ---------------------------------------  26.7/27.4 MB 199.8 kB/s eta 0:00:04
#    ---------------------------------------  26.7/27.4 MB 199.8 kB/s eta 0:00:04
#    ---------------------------------------  26.7/27.4 MB 199.8 kB/s eta 0:00:04
#    ---------------------------------------  26.7/27.4 MB 199.8 kB/s eta 0:00:04
#    ---------------------------------------  27.0/27.4 MB 199.0 kB/s eta 0:00:02
#    ---------------------------------------  27.0/27.4 MB 199.0 kB/s eta 0:00:02
#    ---------------------------------------  27.0/27.4 MB 199.0 kB/s eta 0:00:02
#    ---------------------------------------  27.0/27.4 MB 199.0 kB/s eta 0:00:02
#    ---------------------------------------  27.0/27.4 MB 199.0 kB/s eta 0:00:02
#    ---------------------------------------  27.0/27.4 MB 199.0 kB/s eta 0:00:02
#    ---------------------------------------  27.3/27.4 MB 196.9 kB/s eta 0:00:01
#    ---------------------------------------  27.3/27.4 MB 196.9 kB/s eta 0:00:01
#    ---------------------------------------- 27.4/27.4 MB 197.4 kB/s  0:01:49
# Downloading pandas-3.0.3-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
# ...
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ------------------------- -------------- 11/17 [pandas]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ---------------------------- ----------- 12/17 [multiprocess]
#    ------------------------------ --------- 13/17 [httpx]
#    ------------------------------ --------- 13/17 [httpx]
#    ------------------------------ --------- 13/17 [httpx]
#    ------------------------------ --------- 13/17 [httpx]
#    ------------------------------ --------- 13/17 [httpx]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ----------------------------------- ---- 15/17 [aiohttp]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ------------------------------------- -- 16/17 [datasets]
#    ---------------------------------------- 17/17 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 attrs-26.1.0 datasets-4.8.5 dill-0.4.1 frozenlist-1.8.0 httpcore-1.0.9 httpx-0.28.1 multidict-6.7.1 multiprocess-0.70.19 pandas-3.0.3 propcache-0.5.2 pyarrow-24.0.0 tzdata-2026.2 xxhash-3.7.0 yarl-1.23.0
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: C:\Users\power\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# installation de datasets dans l'environnement ~\anconda3\python.exe
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (4.8.5)
# Requirement already satisfied: filelock in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (3.20.1)
# Requirement already satisfied: numpy>=1.17 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2025.12.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\power\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import torch
import torch.nn as nn
import torch.optim as  optim
import torchvision
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 7
#       5 import torchvision.transforms as T
#       6 from torch.utils.data import Dataset, DataLoader
# ----> 7 from datasets import load_dataset
#       8 import matplotlib.pyplot as plt
#       9 import numpy as np
#
# ModuleNotFoundError: No module named 'datasets'

# %% [markdown]
# ## Image and Text Encoders

# %% [markdown]
# ### Positional Embedding

# %% [markdown]
# ##### Plongement positionnel
# pourquoi : Les Transformers ne savent pas dans quel ordre arrivent les données
# on ajoute des ondes (sinus/cosinus) pour donner une notion de "position" aux données

# %%
class PositionalEmbedding(nn.Module):
  def __init__(self, width, max_seq_length):
    super().__init__()

    pe = torch.zeros(max_seq_length, width)

    for pos in range(max_seq_length):
      for i in range(width):
        if i % 2 == 0:
          pe[pos][i] = np.sin(pos/(10000 ** (i/width)))
        else:
          pe[pos][i] = np.cos(pos/(10000 ** ((i-1)/width)))

    self.register_buffer('pe', pe.unsqueeze(0))

  def forward(self, x):

    x = x + self.pe

    return x

# %% [markdown]
# ## Attention Head

# %%
class AttentionHead(nn.Module):
  def __init__(self, width, head_size):
    super().__init__()
    self.head_size = head_size

    self.query = nn.Linear(width, head_size)
    self.key = nn.Linear(width, head_size)
    self.value = nn.Linear(width, head_size)

  def forward(self, x, mask=None):
    # Obtaining Queries, Keys, and Values
    Q = self.query(x)
    K = self.key(x)
    V = self.value(x)

    # Dot Product of Queries and Keys
    attention = Q @ K.transpose(-2,-1)

    # Scaling
    attention = attention / (self.head_size ** 0.5)

    # Applying Attention Mask
    if mask is not None:
        attention = attention.masked_fill(mask == 0, float("-inf"))

    attention = torch.softmax(attention, dim=-1)

    attention = attention @ V

    return attention

# %% [markdown]
# ## Multi-Head Attention

# %%
class MultiHeadAttention(nn.Module):
  def __init__(self, width, n_heads):
    super().__init__()
    self.head_size = width // n_heads

    self.W_o = nn.Linear(width, width)

    self.heads = nn.ModuleList([AttentionHead(width, self.head_size) for _ in range(n_heads)])

  def forward(self, x, mask=None):
    # Combine attention heads
    out = torch.cat([head(x, mask=mask) for head in self.heads], dim=-1)

    out = self.W_o(out)

    return out

# %% [markdown]
# ## Transformer Encoder

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, width, n_heads, r_mlp=4):
        super().__init__()
        self.width = width
        self.n_heads = n_heads

        # Sub-Layer 1 Normalization
        self.ln1 = nn.LayerNorm(width)

        # Multi-Head Attention
        self.mha = MultiHeadAttention(width, n_heads)

        # Sub-Layer 2 Normalization
        self.ln2 = nn.LayerNorm(width)

        # Multilayer Perception
        self.mlp = nn.Sequential(
            nn.Linear(self.width, self.width*r_mlp),
            nn.GELU(),
            nn.Linear(self.width*r_mlp, self.width)
        )


    def forward(self, x, mask=None):
        x = x + self.mha(self.ln1(x), mask=mask)

        x = x + self.mlp(self.ln2(x))

        return x

# %% [markdown]
# ## Tokenizaton

# %%
def tokenizer(text,encode=True, mask=None, max_seq_length=32):
  if encode:
    out = chr(2) + text + chr(3) # Adding SOT and EOT tokens
    out = out + "".join([chr(0) for _ in range(max_seq_length - len(out))]) # Adding Padding
    out = torch.IntTensor(list(out.encode("utf-8"))) # Encoding Text
    mask = torch.ones(len(out.nonzero()))
    mask = torch.cat((mask,torch.zeros(max_seq_length - len(mask)))).type(torch.IntTensor)
  else:
    out = [chr(x) for x in text[1:len(mask.nonzero()) -1]]
    out = "".join(out)
    mask = None

  return out,mask

# %% [markdown]
# # Text Encoder

# %%
class TextEncoder(nn.Module):
    def __init__(self, vocab_size, width, max_seq_length, n_heads, n_layers, emb_dim):
        super().__init__()

        self.max_seq_length = max_seq_length

        self.encoder_embedding = nn.Embedding(vocab_size, width)

        self.positional_embedding = PositionalEmbedding(width, max_seq_length)

        self.encoder = nn.ModuleList([TransformerEncoder(width,n_heads) for _ in range(n_layers)])

        # learned proj of image to embed
        self.projection = nn.Parameter(torch.randn(width, emb_dim))

    def forward(self, text, mask=None):
        # Text Embedding
        x = self.encoder_embedding(text)

        # Positional Embedding
        x = self.positional_embedding(x)

        # Transformer Encoder
        for encoder_layer in self.encoder:
            x = encoder_layer(x, mask=mask)

        # Takes features from the EOT Embedding
        x = x[torch.arange(text.shape[0]), torch.sub(torch.sum(mask[:,0],dim=1),1)]

        # joint multimodal embedding
        if self.projection is not None:
            x = x @ self.projection

        x = x / torch.norm(x, dim=-1, keepdim=True)

        return x

# %% [markdown]
# ## Image Encoder

# %%
class ImageEncoder(nn.Module):
    def __init__(self, width, img_size, patch_size, n_channels, n_layers, n_heads, emb_dim):
        super().__init__()

        assert img_size[0] % patch_size[0] == 0 and img_size[1] % patch_size[1] == 0, "img_size dimensions must be divisible by patch_size dimensions"
        assert width % n_heads == 0, "width must be divisible by n_heads"

        self.n_patches = (img_size[0] * img_size[1]) // (patch_size[0] * patch_size[1])

        self.max_seq_length = self.n_patches + 1

        self.linear_project = nn.Conv2d(n_channels, width, kernel_size=patch_size, stride=patch_size)

        self.cls_token = nn.Parameter(torch.randn(1, 1, width))

        self.positional_embedding = PositionalEmbedding(width,self.max_seq_length)

        self.encoder = nn.ModuleList([TransformerEncoder(width,n_heads) for _ in range(n_layers)])


        # learned proj of image to embed
        self.projection = nn.Parameter(torch.randn(width, emb_dim))


    def forward(self,x):
        # Patch Embedding
        x = self.linear_project(x)
        x = x.flatten(2).transpose(1, 2)

        # Positional Embedding
        x = torch.cat((self.cls_token.expand(x.size()[0], -1, -1),x), dim=1)
        x = self.positional_embedding(x)

        # Transformer Encoder
        for encoder_layer in self.encoder:
            x = encoder_layer(x)

        # Getting Class Tokens
        x = x[:, 0, :]

        # joint multimodal embedding
        if self.projection is not None:
            x = x @ self.projection

        x = x / torch.norm(x, dim=-1, keepdim=True)

        return x

# %% [markdown]
# ## CLIP Model

# %%
class CLIP(nn.Module):
    def __init__(self, emb_dim, vit_width, img_size, patch_size, n_channels, vit_layers, vit_heads, vocab_size, text_width, max_seq_length, text_heads, text_layers):
        super().__init__()

        self.image_encoder = ImageEncoder(vit_width, img_size, patch_size, n_channels, vit_layers, vit_heads, emb_dim)

        self.text_encoder = TextEncoder(vocab_size, text_width, max_seq_length, text_heads, text_layers, emb_dim)

        self.temperature = nn.Parameter(torch.ones([]) * np.log(1 / 0.07))

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


    def forward(self,image,text, mask=None):
        I_e = self.image_encoder(image)
        T_e = self.text_encoder(text, mask=mask)

        # scaled pairwise cosine similarities [n, n]
        logits = (I_e @ T_e.transpose(-2,-1)) * torch.exp(self.temperature)

        # symmetric loss function
        labels = torch.arange(logits.shape[0]).to(self.device)

        loss_i = nn.functional.cross_entropy(logits.transpose(-2,-1), labels)
        loss_t = nn.functional.cross_entropy(logits, labels)

        loss = (loss_i + loss_t) / 2

        return loss

# %% [markdown]
# ## Dataset

# %%
class FashionMNIST(Dataset):
    def __init__(self, train=True):
        self.dataset = load_dataset("fashion_mnist")

        self.transform = T.ToTensor()

        if train:
            self.split = "train"
        else:
            self.split = "test"


        self.captions = {0: "An image of a t-shirt/top",
                        1: "An image of trousers",
                        2: "An image of a pullover",
                        3: "An image of a dress",
                        4: "An image of a coat",
                        5: "An image of a sandal",
                        6: "An image of a shirt",
                        7: "An image of a sneaker",
                        8: "An image of a bag",
                        9: "An image of an ankle boot"}


    def __len__(self):
        return self.dataset.num_rows[self.split]

    def __getitem__(self,i):
        img = self.dataset[self.split][i]["image"]
        img = self.transform(img)

        cap, mask = tokenizer(self.captions[self.dataset[self.split][i]["label"]])

        mask = mask.repeat(len(mask),1)

        return {"image": img, "caption": cap, "mask": mask}

# %% [markdown]
# ## Training Parameters

# %%
emb_dim = 32
vit_width = 9
img_size = (28,28)
patch_size = (14,14)
n_channels = 1
vit_layers = 3
vit_heads = 3
vocab_size = 256
text_width = 32
max_seq_length = 32
text_heads = 8
text_layers = 4
lr = 1e-3
epochs = 50
batch_size = 128

# %% [markdown]
# ## Loading Dataset

# %%
train_set =  FashionMNIST(train=True)
test_set = FashionMNIST(train=False)

train_loader = DataLoader(train_set,shuffle=True,batch_size=batch_size)
test_loader = DataLoader(test_set,shuffle=False,batch_size=batch_size)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/5.18M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")

model = CLIP(emb_dim, vit_width, img_size, patch_size, n_channels, vit_layers, vit_heads, vocab_size, text_width, max_seq_length, text_heads, text_layers).to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)

best_loss = np.inf
for epoch in range(epochs):
    for i, data in enumerate(train_loader, 0):
        img, cap, mask = data["image"].to(device), data["caption"].to(device), data["mask"].to(device)
        loss = model(img,cap,mask)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch [{epoch+1}/{epochs}], Batch Loss: {loss.item():.3f}")

    # Saves model if it performed better than the previous best
    if loss.item() <= best_loss:
        best_loss = loss.item()
        torch.save(model.state_dict(), "clip.pt")
        print("Model Saved.")
# Out:
# Using device:  cuda (NVIDIA A100-SXM4-40GB)
# Epoch [1/50], Batch Loss: 2.985
# Model Saved.
# Epoch [2/50], Batch Loss: 2.723
# Model Saved.
# Epoch [3/50], Batch Loss: 2.699
# Model Saved.
# Epoch [4/50], Batch Loss: 2.689
# Model Saved.
# Epoch [5/50], Batch Loss: 2.815
# Epoch [6/50], Batch Loss: 2.908
# Epoch [7/50], Batch Loss: 2.760
# Epoch [8/50], Batch Loss: 2.609
# Model Saved.
# Epoch [9/50], Batch Loss: 2.830
# Epoch [10/50], Batch Loss: 2.570
# Model Saved.
# Epoch [11/50], Batch Loss: 2.745
# Epoch [12/50], Batch Loss: 2.731
# Epoch [13/50], Batch Loss: 2.725
# Epoch [14/50], Batch Loss: 2.601
# Epoch [15/50], Batch Loss: 2.636
# Epoch [16/50], Batch Loss: 2.679
# Epoch [17/50], Batch Loss: 2.701
# Epoch [18/50], Batch Loss: 2.741
# Epoch [19/50], Batch Loss: 2.610
# Epoch [20/50], Batch Loss: 2.614
# Epoch [21/50], Batch Loss: 2.584
# Epoch [22/50], Batch Loss: 2.619
# Epoch [23/50], Batch Loss: 2.710
# Epoch [24/50], Batch Loss: 2.597
# Epoch [25/50], Batch Loss: 2.746
# Epoch [26/50], Batch Loss: 2.656
# Epoch [27/50], Batch Loss: 2.669
# Epoch [28/50], Batch Loss: 2.531
# Model Saved.
# Epoch [29/50], Batch Loss: 2.789
# Epoch [30/50], Batch Loss: 2.706
# Epoch [31/50], Batch Loss: 2.599
# Epoch [32/50], Batch Loss: 2.487
# Model Saved.
# Epoch [33/50], Batch Loss: 2.521
# Epoch [34/50], Batch Loss: 2.660
# Epoch [35/50], Batch Loss: 2.692
# Epoch [36/50], Batch Loss: 2.619
# Epoch [37/50], Batch Loss: 2.648
# Epoch [38/50], Batch Loss: 2.768
# Epoch [39/50], Batch Loss: 2.623
# Epoch [40/50], Batch Loss: 2.621
# Epoch [41/50], Batch Loss: 2.650
# Epoch [42/50], Batch Loss: 2.682
# Epoch [43/50], Batch Loss: 2.638
# Epoch [44/50], Batch Loss: 2.601
# Epoch [45/50], Batch Loss: 2.668
# Epoch [46/50], Batch Loss: 2.614
# Epoch [47/50], Batch Loss: 2.726
# Epoch [48/50], Batch Loss: 2.653
# Epoch [49/50], Batch Loss: 2.625
# Epoch [50/50], Batch Loss: 2.568

# %%
# Loading Best Model
model = CLIP(emb_dim, vit_width, img_size, patch_size, n_channels, vit_layers, vit_heads, vocab_size, text_width, max_seq_length, text_heads, text_layers).to(device)
model.load_state_dict(torch.load("clip.pt", map_location=device))

# Getting dataset captions to compare images to
text = torch.stack([tokenizer(x)[0] for x in test_set.captions.values()]).to(device)
mask = torch.stack([tokenizer(x)[1] for x in test_set.captions.values()])
mask = mask.repeat(1,len(mask[0])).reshape(len(mask),len(mask[0]),len(mask[0])).to(device)

correct, total = 0,0
with torch.no_grad():
    for data in test_loader:
        images, labels = data["image"].to(device), data["caption"].to(device)
        image_features = model.image_encoder(images)
        text_features = model.text_encoder(text, mask=mask)

        image_features /= image_features.norm(dim=-1, keepdim=True)
        text_features /= text_features.norm(dim=-1, keepdim=True)
        similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)
        _, indices = torch.max(similarity,1)
        pred = torch.stack([tokenizer(test_set.captions[int(i)])[0] for i in indices]).to(device)
        correct += int(sum(torch.sum((pred==labels),dim=1)//len(pred[0])))
        total += len(labels)

print(f'\nModel Accuracy: {100 * correct // total} %')
# Out:
# Model Accuracy: 85 %

# %%
# Loading Best Model
model = CLIP(emb_dim, vit_width, img_size, patch_size, n_channels, vit_layers, vit_heads, vocab_size, text_width, max_seq_length, text_heads, text_layers).to(device)
model.load_state_dict(torch.load("clip.pt", map_location=device))


# Captions to compare images to
class_names =["t-shirt/top","trousers","pullover","dress","coat","sandal","shirt","sneaker","bag","ankle boot"]

text = torch.stack([tokenizer(x)[0] for x in class_names]).to(device)
mask = torch.stack([tokenizer(x)[1] for x in class_names])
mask = mask.repeat(1,len(mask[0])).reshape(len(mask),len(mask[0]),len(mask[0])).to(device)

idx = 1000

img = test_set[idx]["image"][None,:]
plt.imshow(img[0].permute(1, 2, 0)  ,cmap="gray")
plt.title(tokenizer(test_set[idx]["caption"], encode=False, mask=test_set[idx]["mask"][0])[0])
plt.show()
img = img.to(device)
with torch.no_grad():
  image_features = model.image_encoder(img)
  text_features = model.text_encoder(text, mask=mask)


image_features /= image_features.norm(dim=-1, keepdim=True)
text_features /= text_features.norm(dim=-1, keepdim=True)
similarity = (100.0 * image_features @ text_features.T).softmax(dim=-1)
values, indices = similarity[0].topk(5)

# Print the result
print("\nTop predictions:\n")
for value, index in zip(values, indices):
    print(f"{class_names[int(index)]:>16s}: {100 * value.item():.2f}%")
# Out:
# Top predictions:
#
#            shirt: 52.37%
#      t-shirt/top: 47.63%
#         pullover: 0.00%
#            dress: 0.00%
#         trousers: 0.00%
